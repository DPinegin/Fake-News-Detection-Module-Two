# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
import re,string,unicodedata
from keras.preprocessing import text, sequence
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet
import keras
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,Dropout
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Drdr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fake = pd.read_csv(r'C:\Users\Drdr\Desktop\Fake News Detection\extension\server\archive (3)/Fake.csv')
true = pd.read_csv(r'C:\Users\Drdr\Desktop\Fake News Detection\extension\server\archive (3)/True.csv')

# %%
true['category'] = 1
fake['category'] = 0

# %%
df = pd.concat([true,fake])
#Merging the the two datastes, Fake and True together

# %%
sns.set_style("darkgrid")
sns.countplot(df.category)
# Out:
# c:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='category', ylabel='count'>

# %%
df.head()
# Out:
#                                                title  \
# 0                     Graphic: Supreme Court roundup
# 1  White House: Trump speaks with Egypt's Sisi by...
# 2  Spain's cabinet to hold special meeting at 170...
# 3    UK PM May wants to be a strong friend to the EU
# 4  Russia's Putin says we will be able to solve t...
#
#                                                 text       subject       date  \
# 0                                                     politicsNews  16-Jun-16
# 1  WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews  23-Jan-17
# 2  MADRID (Reuters) - Spain s cabinet will hold a...     worldnews  31-Oct-17
# 3  FLORENCE, Italy (Reuters) - Britain wants to b...     worldnews  22-Sep-17
# 4  VLADIVOSTOK, Russia (Reuters) - Russian Presid...     worldnews  07-Sep-17
#
#    label  characters  category  Unnamed: 5
# 0      0           1         1         NaN
# 1      0         152         1         NaN
# 2      0         152         1         NaN
# 3      0         156         1         NaN
# 4      0         157         1         NaN

# %%
df.isna().sum() # Checking for nan Values
# Out:
# title             0
# text              0
# subject           0
# date              0
# label             0
# characters        0
# category          0
# Unnamed: 5    44898
# dtype: int64

# %%
df.title.count()
# Out:
# 44898

# %%
#merging all the data into one column
plt.figure(figsize = (12,8))
sns.set(style = "whitegrid",font_scale = 1.2)
chart = sns.countplot(x = "subject", hue = "category" , data = df)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'politicsNews'),
#  Text(1, 0, 'worldnews'),
#  Text(2, 0, 'politics'),
#  Text(3, 0, 'Government News'),
#  Text(4, 0, 'left-news'),
#  Text(5, 0, ' Politics According to the Bible and (with Barry Asmus) The Poverty of Nations: A Sustainable Solution.Via: Townhall"'),
#  Text(6, 0, ' decided not to seek re-election. While much of the mainstream media waxed poetic about his 30-year career'),
#  Text(7, 0, ' of which Soros is a major financier.Mercy Corps: Vis a vis the Arab-Israeli conflict'),
#  Text(8, 0, ' claimed that hundreds of alternative media websites were producing  fake news  and  conspiracy  stories and therefore were unreliable as information sources. It wasn t long before the establishment began referencing these politicized lists'),
#  Text(9, 0, ' fell 5.6 percent Monday. Wynn Resortsslipped 1.2 percent. Las Vegas Sands fell as much as 2.1 percent before closing higher.   LIVE DRILL    Las Vegas has been at the forefront of active shooter training. ( Image Source: sinclairstoryline)Las Vegas Active Shooter Drills Back in 2014'),
#  Text(10, 0, ' Karl Marx is either a villain or a hero of social engineering'),
#  Text(11, 0, ' a future nuclear family'),
#  Text(12, 0, 'US_News'),
#  Text(13, 0, 'Middle-east'),
#  Text(14, 0, ' state systems with outsized pretensions to power have reacted to their environments in two ways. The first strategy'),
#  Text(15, 0, ' the defense industry'),
#  Text(16, 0, 'News'),
#  Text(17, 0, ' and so is Mr. Katzenbach'),
#  Text(18, 0, ' high taxes')]

# %%
plt.figure(figsize = (12,8))
sns.set(style = "whitegrid",font_scale = 1.2)
chart = sns.countplot(x = "subject", hue = "category" , data = df)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'politicsNews'),
#  Text(1, 0, 'worldnews'),
#  Text(2, 0, 'politics'),
#  Text(3, 0, 'Government News'),
#  Text(4, 0, 'left-news'),
#  Text(5, 0, ' Politics According to the Bible and (with Barry Asmus) The Poverty of Nations: A Sustainable Solution.Via: Townhall"'),
#  Text(6, 0, ' decided not to seek re-election. While much of the mainstream media waxed poetic about his 30-year career'),
#  Text(7, 0, ' of which Soros is a major financier.Mercy Corps: Vis a vis the Arab-Israeli conflict'),
#  Text(8, 0, ' claimed that hundreds of alternative media websites were producing  fake news  and  conspiracy  stories and therefore were unreliable as information sources. It wasn t long before the establishment began referencing these politicized lists'),
#  Text(9, 0, ' fell 5.6 percent Monday. Wynn Resortsslipped 1.2 percent. Las Vegas Sands fell as much as 2.1 percent before closing higher.   LIVE DRILL    Las Vegas has been at the forefront of active shooter training. ( Image Source: sinclairstoryline)Las Vegas Active Shooter Drills Back in 2014'),
#  Text(10, 0, ' Karl Marx is either a villain or a hero of social engineering'),
#  Text(11, 0, ' a future nuclear family'),
#  Text(12, 0, 'US_News'),
#  Text(13, 0, 'Middle-east'),
#  Text(14, 0, ' state systems with outsized pretensions to power have reacted to their environments in two ways. The first strategy'),
#  Text(15, 0, ' the defense industry'),
#  Text(16, 0, 'News'),
#  Text(17, 0, ' and so is Mr. Katzenbach'),
#  Text(18, 0, ' high taxes')]

# %%
#Merging df and the third dataset together
df1 = pd.concat([df])
df1
# Out:
#                                                    title  \
# 0                         Graphic: Supreme Court roundup
# 1      White House: Trump speaks with Egypt's Sisi by...
# 2      Spain's cabinet to hold special meeting at 170...
# 3        UK PM May wants to be a strong friend to the EU
# 4      Russia's Putin says we will be able to solve t...
# ...                                                  ...
# 23476  ANOTHER AMERICAN KNOWN WOLF? Fort Lauderdale S...
# 23477  ORLANDO ‘KNOWN WOLF’ Watched by FBI, Worked wi...
# 23478  ORLANDO ‘KNOWN WOLF’ Watched by FBI, Worked wi...
# 23479  AN AMERICAN TRAGEDY: Who Really Killed JonBené...
# 23480  AN AMERICAN TRAGEDY: Who Really Killed JonBené...
#
#                                                     text       subject  \
# 0                                                         politicsNews
# 1      WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 2      MADRID (Reuters) - Spain s cabinet will hold a...     worldnews
# 3      FLORENCE, Italy (Reuters) - Britain wants to b...     worldnews
# 4      VLADIVOSTOK, Russia (Reuters) - Russian Presid...     worldnews
# ...                                                  ...           ...
# 23476  Shawn Helton 21st Century WireAnother shocking...   Middle-east
# 23477   Shawn Helton  21st Century WireOrlando s Puls...       US_News
# 23478   Shawn Helton  21st Century WireOrlando s Puls...   Middle-east
# 23479   Do roses know their thorns can hurt?    a quo...       US_News
# 23480   Do roses know their thorns can hurt?    a quo...   Middle-east
#
#             date  label  characters  category  Unnamed: 5
# 0      16-Jun-16      0           1         1         NaN
# 1      23-Jan-17      0         152         1         NaN
# 2      31-Oct-17      0         152         1         NaN
# 3      22-Sep-17      0         156         1         NaN
# 4      07-Sep-17      0         157         1         NaN
# ...          ...    ...         ...       ...         ...
# 23476  07-Jan-17      1       31069         0         NaN
# 23477  16-Jun-16      1       31896         0         NaN
# 23478  16-Jun-16      1       31896         0         NaN
# 23479  23-Sep-16      1       32655         0         NaN
# 23480  23-Sep-16      1       32655         0         NaN
#
# [44898 rows x 8 columns]

# %%
del df1['subject']
del df1['date']
df1['text'] = df1['text'] + " " + df1['title']
del df1['title']

# %%
nltk.download('words')
words = set(nltk.corpus.words.words())

sent = str(df1)
" ".join(w for w in nltk.wordpunct_tokenize(sent) \
         if w.lower() in words or not w.isalpha())
# 'Io to the beach with my'
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Drdr\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# 'text label \\ 0 Graphic : Supreme Court roundup 0 1 1 ( ) - U . S . President T ... 0 152 2 ( ) - s cabinet will hold a ... 0 152 3 FLORENCE , ( ) - to b ... 0 156 4 , Russia ( ) - ... 0 157 ... ... ... ... 23476 21st Century shocking ... 1 31069 23477 21st Century s ... 1 31896 23478 21st Century s ... 1 31896 23479 Do know their can hurt ? a quo ... 1 32655 23480 Do know their can hurt ? a quo ... 1 32655 category Unnamed : 5 0 1 NaN 1 1 NaN 2 1 NaN 3 1 NaN 4 1 NaN ... ... ... 23476 0 NaN 23477 0 NaN 23478 0 NaN 23479 0 NaN 23480 0 NaN [ 44898 x 5 ]'

# %%
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)
#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            final_text.append(i.strip())
    return " ".join(final_text)
#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    return text

# %%
df1['text']= df1['text'].apply(str)
df1['text']=df1['text'].apply(denoise_text)
# Out:
# C:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
plt.figure(figsize = (20,20)) # Text that is not Fake
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(" ".join(df1[df1.category == 1].text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
plt.figure(figsize = (20,20)) # Text that is Fake
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800 , stopwords = STOPWORDS).generate(" ".join(df1[df1.category == 0].text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,8))
text_len=df1[df1['category']==1]['text'].str.len()
ax1.hist(text_len,color='red')
ax1.set_title('Original text')
text_len=df1[df1['category']==0]['text'].str.len()
ax2.hist(text_len,color='green')
ax2.set_title('Fake text')
fig.suptitle('Characters in texts')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,8))
text_len=df1[df1['category']==1]['text'].str.split().map(lambda x: len(x))
ax1.hist(text_len,color='red')
ax1.set_title('Original text')
text_len=df1[df1['category']==0]['text'].str.split().map(lambda x: len(x))
ax2.hist(text_len,color='green')
ax2.set_title('Fake text')
fig.suptitle('Words in texts')
plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(20,10))
word=df1[df1['category']==1]['text'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(word.map(lambda x: np.mean(x)),ax=ax1,color='red')
ax1.set_title('Original text')
word=df1[df1['category']==0]['text'].str.split().apply(lambda x : [len(i) for i in x])
sns.distplot(word.map(lambda x: np.mean(x)),ax=ax2,color='green')
ax2.set_title('Fake text')
fig.suptitle('Average word length in each text')
# Out:
# c:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0.98, 'Average word length in each text')

# %%
def get_corpus(text):
    words = []
    for i in text:
        for j in i.split():
            words.append(j.strip())
    return words
corpus = get_corpus(df1.text)
corpus[:5]
# Out:
# ['Graphic:', 'Supreme', 'Court', 'roundup', 'WASHINGTON']

# %%
from collections import Counter
counter = Counter(corpus)
most_common = counter.most_common(10)
most_common = dict(most_common)
most_common

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_top_text_ngrams(corpus, n, g):
    vec = CountVectorizer(ngram_range=(g, g)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
plt.figure(figsize = (16,9))
most_common_uni = get_top_text_ngrams(df1.text,10,1)
most_common_uni = dict(most_common_uni)
sns.barplot(x=list(most_common_uni.values()),y=list(most_common_uni.keys()))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (16,9))
most_common_bi = get_top_text_ngrams(df1.text,10,2)
most_common_bi = dict(most_common_bi)
sns.barplot(x=list(most_common_bi.values()),y=list(most_common_bi.keys()))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (16,9))
most_common_tri = get_top_text_ngrams(df1.text,10,3)
most_common_tri = dict(most_common_tri)
sns.barplot(x=list(most_common_tri.values()),y=list(most_common_tri.keys()))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (16,9))
most_common_tri = get_top_text_ngrams(df1.text,10,3)
most_common_tri = dict(most_common_tri)
sns.barplot(x=list(most_common_tri.values()),y=list(most_common_tri.keys()))
# Out:
# <AxesSubplot:>

# %%
x_train,x_test,y_train,y_test = train_test_split(df1.text,df1.category,random_state = 10)
x_train

# %%
max_features = 10000
maxlen = 300

# %%
#tokenizer = text.Tokenizer(num_words=max_features)
#tokenizer.fit_on_texts(x_train)
#tokenized_train = tokenizer.texts_to_sequences(x_train)
#x_train = keras.utils.pad_sequences(tokenized_train, maxlen=maxlen)
tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(x_train)
tokenized_train = tokenizer.texts_to_sequences(x_train)
x_train = sequence.pad_sequences(tokenized_train, maxlen=maxlen)

tokenized_test = tokenizer.texts_to_sequences(x_test)
X_test = keras.utils.pad_sequences(tokenized_test, maxlen=maxlen)

#tokenized_test = tokenizer.texts_to_sequences(x_test)
#X_test = sequence.pad_sequences(tokenized_test, maxlen=maxlen)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 6>()
#       1 #tokenizer = text.Tokenizer(num_words=max_features)
#       2 #tokenizer.fit_on_texts(x_train)
#       3 #tokenized_train = tokenizer.texts_to_sequences(x_train)
#       4 #x_train = keras.utils.pad_sequences(tokenized_train, maxlen=maxlen)
#       5 tokenizer = text.Tokenizer(num_words=max_features)
# ----> 6 tokenizer.fit_on_texts(x_train)
#       7 tokenized_train = tokenizer.texts_to_sequences(x_train)
#       8 x_train = sequence.pad_sequences(tokenized_train, maxlen=maxlen)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\text.py:222, in Tokenizer.fit_on_texts(self, texts)
#     220     seq = text
#     221 else:
# --> 222     seq = text_to_word_sequence(text,
#     223                                 self.filters,
#     224                                 self.lower,
#     225                                 self.split)
#     226 for w in seq:
#     227     if w in self.word_counts:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras_preprocessing\text.py:43, in text_to_word_sequence(text, filters, lower, split)
#      29 """Converts a text to a sequence of words (or tokens).
#      30
#      31 # Arguments
#    (...)
#      40     A list of words (or tokens).
#      41 """
#      42 if lower:
# ---> 43     text = text.lower()
#      45 if sys.version_info < (3,):
#      46     if isinstance(text, unicode):  # noqa: F821
#
# AttributeError: 'numpy.ndarray' object has no attribute 'lower'

# %%
tokenized_test = tokenizer.texts_to_sequences(x_test)
X_test = keras.utils.pad_sequences(tokenized_test, maxlen=maxlen)

# %%
EMBEDDING_FILE = r'C:\Users\Drdr\Desktop\Fake News Detection\extension\server\glove.twitter.27B.100d.txt'
file = open(EMBEDDING_FILE, encoding="utf-8")
def get_coefs(word, *arr): 
    return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.rstrip().rsplit(' ')) for o in open('glove.twitter.27B.100d.txt', 'r', encoding='utf-8'))

# %%
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]

#max_features = 10000
#tokenizer= text.Tokenizer()
word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
#change below line if computing normal stats is too slow
embedding_matrix = embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
# Out:
# c:\Users\Drdr\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3309: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   if await self.run_code(code, result, async_=asy):

# %%
batch_size = 256
epochs = 10
embed_size = 100
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.5, min_lr=0.00001)

# %%
from tensorflow import keras
#Defining Neural Network
model = Sequential()
#Non-trainable embeddidng layer
model.add(Embedding(max_features, output_dim=embed_size, weights=[embedding_matrix], input_length=maxlen, trainable=False))
#LSTM 
model.add(LSTM(units=128 , return_sequences = True , recurrent_dropout = 0.25 , dropout = 0.25))
model.add(LSTM(units=64 , recurrent_dropout = 0.1 , dropout = 0.1))
model.add(Dense(units = 32 , activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.01), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 100)          1000000
#
#  lstm (LSTM)                 (None, 300, 128)          117248
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,168,769
# Trainable params: 168,769
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, batch_size = batch_size , validation_data = (X_test,y_test) , epochs = epochs , callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/10
# 132/132 [==============================] - 5013s 38s/step - loss: 0.1633 - accuracy: 0.9290 - val_loss: 0.0870 - val_accuracy: 0.9683 - lr: 0.0100
# Epoch 2/10
# 132/132 [==============================] - 5746s 44s/step - loss: 0.0288 - accuracy: 0.9908 - val_loss: 0.0098 - val_accuracy: 0.9971 - lr: 0.0100
# Epoch 3/10
# 132/132 [==============================] - 6040s 46s/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.0127 - val_accuracy: 0.9958 - lr: 0.0100
# Epoch 4/10
# 132/132 [==============================] - 6248s 47s/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0083 - val_accuracy: 0.9983 - lr: 0.0100
# Epoch 5/10
# 132/132 [==============================] - 6360s 48s/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0089 - val_accuracy: 0.9974 - lr: 0.0100
# Epoch 6/10
# 132/132 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9987
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 132/132 [==============================] - 6386s 48s/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0069 - val_accuracy: 0.9984 - lr: 0.0100
# Epoch 7/10
# 132/132 [==============================] - 6533s 50s/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0069 - val_accuracy: 0.9980 - lr: 0.0050
# Epoch 8/10
# 132/132 [==============================] - 6670s 51s/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0048 - val_accuracy: 0.9988 - lr: 0.0050
# Epoch 9/10
# 132/132 [==============================] - 6802s 52s/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 0.0045 - val_accuracy: 0.9991 - lr: 0.0050
# Epoch 10/10
# 132/132 [==============================] - 6788s 51s/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0047 - val_accuracy: 0.9992 - lr: 0.0050

# %%
print("Accuracy of the model on Training Data is - " , model.evaluate(x_train,y_train)[1]*100 , "%")
print("Accuracy of the model on Testing Data is - " , model.evaluate(X_test,y_test)[1]*100 , "%")
# Out:
# 1053/1053 [==============================] - 220s 209ms/step - loss: 9.0892e-05 - accuracy: 1.0000
# Accuracy of the model on Training Data is -  99.99703168869019 %
# 351/351 [==============================] - 73s 208ms/step - loss: 0.0047 - accuracy: 0.9992
# Accuracy of the model on Testing Data is -  99.91981983184814 %

# %%
epochs = [i for i in range(10)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Testing Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'go-' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'ro-' , label = 'Testing Loss')
ax[1].set_title('Training & Testing Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %%
threshold = 0.5
predict_x=model.predict(X_test) 
predict_x[predict_x <=threshold] = 0
predict_x[predict_x > (1 - threshold)] = 1
predict_x[:10]
# Out:
# 351/351 [==============================] - 68s 192ms/step
# array([[1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.]], dtype=float32)

# %%
print(classification_report(y_test, predict_x, target_names = ['Fake','Not Fake']))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       1.00      1.00      1.00      5892
#     Not Fake       1.00      1.00      1.00      5333
#
#     accuracy                           1.00     11225
#    macro avg       1.00      1.00      1.00     11225
# weighted avg       1.00      1.00      1.00     11225

# %%
cm = confusion_matrix(y_test,predict_x)
cm
# Out:
# array([[5888,    4],
#        [   5, 5328]], dtype=int64)

# %%
cm = pd.DataFrame(cm , index = ['Fake','Original'] , columns = ['Fake','Original'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='' , xticklabels = ['Fake','Original'] , yticklabels = ['Fake','Original'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(64.5, 0.5, 'Actual')

# %%
model.save("erast.h5")
#h5 lets you store large amounts of data that can be manipulated by using numPy
# Model can be trained by running python3 Flask_Train.py which generates my_model.h5
#model.save('saved_model/1/')
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_model/1/assets
# INFO:tensorflow:Assets written to: saved_model/1/assets

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [41], in <cell line: 17>()
#      14 lstm = model.layers[2]
#      16 # Get output from intermediate layer to visualize activations
# ---> 17 attn_func = K.function(inputs = [model.get_input_at(0), K.learning_phase()],
#      18            outputs = [lstm.output]
#      19           )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py:2112, in Layer.get_input_at(self, node_index)
#    2096 @doc_controls.do_not_doc_inheritable
#    2097 def get_input_at(self, node_index):
#    2098   """Retrieves the input tensor(s) of a layer at a given node.
#    2099
#    2100   Args:
#    (...)
#    2110     RuntimeError: If called in Eager mode.
#    2111   """
# -> 2112   return self._get_node_attribute_at_index(node_index, 'input_tensors',
#    2113                                            'input')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\base_layer.py:2701, in Layer._get_node_attribute_at_index(self, node_index, attr, attr_name)
#    2678 """Private utility to retrieves an attribute (e.g. inputs) from a node.
#    2679
#    2680 This is used to implement the methods:
#    (...)
#    2698     ValueError: If the index provided does not match any node.
#    2699 """
#    2700 if not self._inbound_nodes:
# -> 2701   raise RuntimeError(f'The layer {self.name} has never been called '
#    2702                      'and thus has no defined {attr_name}.')
#    2703 if not len(self._inbound_nodes) > node_index:
#    2704   raise ValueError(f'Asked to get {attr_name} at node '
#    2705                    f'{node_index}, but the layer has only '
#    2706                    f'{len(self._inbound_nodes)} inbound nodes.')
#
# RuntimeError: The layer sequential has never been called and thus has no defined {attr_name}.

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)
#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            final_text.append(i.strip())
    return " ".join(final_text)
#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    return text

testing['text']= testing['text'].apply(str)
testing['text']=testing['text'].apply(denoise_text)

def get_corpus(text):
    words = []
    for i in text:
        for j in i.split():
            words.append(j.strip())
    return words
corpus = get_corpus(testing.text)
corpus[:5]
# Out:
# ['PARIS,', 'Oct', '3', '(Reuters)', 'Apple?s']

# %%
from collections import Counter
counter1 = Counter(corpus)
most_common = counter1.most_common(10)
most_common = dict(most_common)
most_common
# Out:
# {'said': 49,
#  'would': 46,
#  'Trump': 31,
#  'U.S.': 24,
#  'also': 21,
#  'United': 20,
#  'new': 20,
#  'percent': 19,
#  'one': 17,
#  'could': 16}

# %%
from sklearn.feature_extraction.text import CountVectorizer
def get_top_text_ngrams(corpus, n, g):
    vec1 = CountVectorizer(ngram_range=(g, g)).fit(corpus)
    bag_of_words1 = vec1.transform(corpus)
    sum_words1 = bag_of_words1.sum(axis=0) 
    words_freq1 = [(word, sum_words1[0, idx]) for word, idx in vec1.vocabulary_.items()]
    words_freq1 =sorted(words_freq1, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
x_train,x_test,y_train,y_test = train_test_split(testing.text,testing.category,random_state = 10)
x_test
# Out:
# 7     WASHINGTON, DC?The American President Donald T...
# 5     2016 presidential election surreal record, it?...
# 18    PALM BEACH, Fla/WASHINGTON (Reuters) Millions ...
# 21    NEWSWATCH33 National Research Center commissio...
# 11    Next News Network host founder Gary Franchi br...
# 1     September 11, 2001, world changed forever. Eve...
# 2     WASHINGTON (Reuters) White House said Sunday c...
# Name: text, dtype: object

# %%
tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(x_train)
tokenized_train = tokenizer.texts_to_sequences(x_train)
x_train = sequence.pad_sequences(tokenized_train, maxlen=maxlen)

# %%
#predictions = new_model.predict(testing, batch_size=10, verbose=0)
tokenized_test = tokenizer.texts_to_sequences(x_test)
X_test = sequence.pad_sequences(tokenized_test, maxlen=maxlen)

# %%
EMBEDDING_FILE = r'C:\Users\Drdr\Desktop\PythonProjects\Fake News Detection\glove.twitter.27B.100d.txt'

# %%
file = open(EMBEDDING_FILE, encoding="utf-8")
def get_coefs(word, *arr): 
    return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.rstrip().rsplit(' ')) for o in open('glove.twitter.27B.100d.txt', 'r', encoding='utf-8'))

# %%
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]

#max_features = 10000
#tokenizer= text.Tokenizer()
word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
#change below line if computing normal stats is too slow
embedding_matrix = embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
